# %% [markdown]
# **Final Report: Performance Analysis and Ranking of Finance Accounts**
#
# ---
#
# ## **1. Introduction**
# This report presents a detailed analysis of historical trade data from various Binance accounts over a 90-day period. The goal of this analysis is to compute key financial metrics for each account, rank them based on performance, and provide a list of the top 20 accounts.
#
# ## **2. Data Preprocessing**
# ### **2.1 Dataset Overview**
# The dataset consists of:
# - **Port_IDs**: Unique identifier for each account.
# - **Trade_History**: A JSON-like structure containing trade details, including timestamp, asset, side (BUY/SELL), price, quantity, and realized profit/loss.
#
# ### **2.2 Data Cleaning and Parsing**
# - Missing values in `Trade_History` were identified and removed.
# - The `Trade_History` column was converted from a JSON-like string into a structured format.
# - Key trade details for each account were extracted into separate DataFrames for further analysis.
#
# ## **3. Financial Metrics Calculation**
# For each account, the following financial metrics were computed:
#
# ### **3.1 Return on Investment (ROI)**
# \[ ROI = \frac{\text{Net Profit}}{\text{Total Investment}} \times 100 \]
# - **Net Profit**: Sum of `realizedProfit` across all trades.
# - **Total Investment**: Sum of `quantity` used in all trades.
#
# ### **3.2 Profit and Loss (PnL)**
# \[ PnL = \sum \text{realizedProfit} \]
# - Measures the total profitability or loss of an account.
#
# ### **3.3 Sharpe Ratio**
# \[ Sharpe Ratio = \frac{\text{Mean Returns}}{\text{Standard Deviation of Returns}} \]
# - Measures risk-adjusted returns. A higher Sharpe Ratio indicates better returns per unit of risk.
#
# ### **3.4 Maximum Drawdown (MDD)**
# \[ MDD = \frac{\text{Peak Portfolio Value} - \text{Lowest Portfolio Value}}{\text{Peak Portfolio Value}} \]
# - Represents the worst percentage drop in portfolio value from peak to trough.
#
# ### **3.5 Win Rate & Positions**
# - **Win Rate** = Percentage of trades that resulted in a profit.
# - **Win Positions** = Number of profitable trades.
# - **Total Positions** = Total number of trades executed.
#
# ## **4. Ranking Methodology**
# Each account was ranked based on a weighted scoring system:
# \[ Score = 0.4 \times ROI + 0.2 \times Sharpe Ratio + 0.2 \times Win Rate + 0.1 \times PnL - 0.1 \times MDD \]
#
# - **ROI (40%)**: Higher ROI is preferred.
# - **Sharpe Ratio (20%)**: Penalizes volatile returns.
# - **Win Rate (20%)**: Measures consistency in profitability.
# - **PnL (10%)**: Prioritizes accounts with higher profits.
# - **MDD (-10%)**: Penalizes accounts with higher drawdowns.
#
# The final rankings were determined based on the computed scores, and the top 20 accounts were selected.
#
# ## **5. Findings & Insights**
# - Accounts with high ROI and Sharpe Ratios generally performed well.
# - Some accounts had high win rates but lower PnL, indicating small but frequent profits.
# - Accounts with significant drawdowns (high MDD) were penalized in rankings due to increased risk.
# - A balanced approach between profitability and risk-adjusted returns led to better ranking scores.
#
# ## **6. Deliverables**
# - **Jupyter Notebook/Python Script**: Contains the full analysis and computations.
# - **Calculated Metrics CSV (calculated_metrics.csv)**: Includes all computed metrics for each account.
# - **Top 20 Accounts CSV (top_20_accounts.csv)**: Lists the top 20 ranked accounts.
# - **This Final Report**: Summarizes methodology, findings, and assumptions.
#
# ---
#
# This report provides a comprehensive assessment of Binance trading accounts, identifying top-performing traders based on quantitative metrics and ranking methodology.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(r'E:\Data Set\csv file\TRADES_CopyTr_90D_ROI.csv')

# %%
data.head(5)
# Out:
#               Port_IDs                                      Trade_History
# 0  3925368433214965504  [{'time': 1718899656000, 'symbol': 'SOLUSDT', ...
# 1  4002413037164645377  [{'time': 1718980078000, 'symbol': 'NEARUSDT',...
# 2  3923766029921022977  [{'time': 1718677164000, 'symbol': 'ETHUSDT', ...
# 3  3994879592543698688  [{'time': 1718678214000, 'symbol': 'ETHUSDT', ...
# 4  3926423286576838657  [{'time': 1718979615000, 'symbol': 'ETHUSDT', ...

# %%
data.shape
# Out:
# (150, 2)

# %%
data.isnull().sum()
# Out:
# Port_IDs         0
# Trade_History    1
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Port_IDs       150 non-null    int64
#  1   Trade_History  149 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.5+ KB

# %%
data.dtypes
# Out:
# Port_IDs          int64
# Trade_History    object
# dtype: object

# %% [markdown]
# # Handing Missing Values

# %%
data = data.dropna(subset=['Trade_History'])

# %%
data.isnull().sum()
# Out:
# Port_IDs         0
# Trade_History    0
# dtype: int64

# %%
import ast
data['Trade_History'] = data['Trade_History'].apply(ast.literal_eval)

# %%
data.head(3)
# Out:
#               Port_IDs                                      Trade_History
# 0  3925368433214965504  [{'time': 1718899656000, 'symbol': 'SOLUSDT', ...
# 1  4002413037164645377  [{'time': 1718980078000, 'symbol': 'NEARUSDT',...
# 2  3923766029921022977  [{'time': 1718677164000, 'symbol': 'ETHUSDT', ...

# %%
data['Trade_History'][0]
# Out:
# [{'time': 1718899656000,
#   'symbol': 'SOLUSDT',
#   'side': 'BUY',
#   'price': 132.537,
#   'fee': -0.9940275,
#   'feeAsset': 'USDT',
#   'quantity': 1988.055,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'SOL',
#   'qty': 15.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718899618000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12182,
#   'fee': -0.27979617,
#   'feeAsset': 'USDT',
#   'quantity': 1398.98088,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 11484.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718899618000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12182,
#   'fee': -0.03949404,
#   'feeAsset': 'USDT',
#   'quantity': 197.47022,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 1621.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718899616000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12182,
#   'fee': -0.00828375,
#   'feeAsset': 'USDT',
#   'quantity': 16.56752,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 136.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718899616000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12182,
#   'fee': -0.04610887,
#   'feeAsset': 'USDT',
#   'quantity': 92.21774,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 757.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718899616000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12182,
#   'fee': -0.12571824,
#   'feeAsset': 'USDT',
#   'quantity': 251.43648,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 2064.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718899616000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12182,
#   'fee': -0.02180578,
#   'feeAsset': 'USDT',
#   'quantity': 43.61156,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 358.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718899607000,
#   'symbol': 'SOLUSDT',
#   'side': 'BUY',
#   'price': 132.585,
#   'fee': -0.159102,
#   'feeAsset': 'USDT',
#   'quantity': 795.51,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'SOL',
#   'qty': 6.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718899607000,
#   'symbol': 'SOLUSDT',
#   'side': 'BUY',
#   'price': 132.585,
#   'fee': -0.5966325,
#   'feeAsset': 'USDT',
#   'quantity': 1193.265,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'SOL',
#   'qty': 9.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718889684000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.454,
#   'fee': -0.3485255,
#   'feeAsset': 'USDT',
#   'quantity': 697.051,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 156.5,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718889684000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.454,
#   'fee': -0.0031178,
#   'feeAsset': 'USDT',
#   'quantity': 6.2356,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 1.4,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718889684000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.454,
#   'fee': -0.13361999,
#   'feeAsset': 'USDT',
#   'quantity': 267.24,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 60.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718889684000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.454,
#   'fee': -0.5146597,
#   'feeAsset': 'USDT',
#   'quantity': 1029.3194,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 231.1,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718889588000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.471,
#   'fee': -0.16565055,
#   'feeAsset': 'USDT',
#   'quantity': 331.3011,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 74.1,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718889588000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.471,
#   'fee': -0.13413,
#   'feeAsset': 'USDT',
#   'quantity': 268.26,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 60.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718889588000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.471,
#   'fee': -0.67065,
#   'feeAsset': 'USDT',
#   'quantity': 1341.3,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 300.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718889588000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.471,
#   'fee': -0.0295086,
#   'feeAsset': 'USDT',
#   'quantity': 59.0172,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 13.2,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.525,
#   'fee': -0.01925212,
#   'feeAsset': 'USDT',
#   'quantity': 38.50425,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.33256281,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.57,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.525,
#   'fee': -0.100062,
#   'feeAsset': 'USDT',
#   'quantity': 200.124,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 6.92593156,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.16,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.525,
#   'fee': -0.25751249,
#   'feeAsset': 'USDT',
#   'quantity': 515.025,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 17.82408858,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 21.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.526,
#   'fee': -0.10006608,
#   'feeAsset': 'USDT',
#   'quantity': 200.13216,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 6.93409156,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.16,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.526,
#   'fee': -0.20000953,
#   'feeAsset': 'USDT',
#   'quantity': 400.01906,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 13.85968547,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 16.31,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.526,
#   'fee': -0.10006608,
#   'feeAsset': 'USDT',
#   'quantity': 200.13216,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 6.93409156,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.16,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.526,
#   'fee': -0.3347799,
#   'feeAsset': 'USDT',
#   'quantity': 669.5598,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 23.19861516,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 27.3,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.526,
#   'fee': -0.01508349,
#   'feeAsset': 'USDT',
#   'quantity': 30.16698,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.04521233,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.23,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.526,
#   'fee': -0.01508349,
#   'feeAsset': 'USDT',
#   'quantity': 30.16698,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.04521233,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.23,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.10007016,
#   'feeAsset': 'USDT',
#   'quantity': 200.14032,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 6.94225156,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.16,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.10007016,
#   'feeAsset': 'USDT',
#   'quantity': 200.14032,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 6.94225156,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.16,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.20001768,
#   'feeAsset': 'USDT',
#   'quantity': 400.03537,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 13.87599547,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 16.31,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.02930976,
#   'feeAsset': 'USDT',
#   'quantity': 58.61953,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 2.03333103,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 2.39,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.03544151,
#   'feeAsset': 'USDT',
#   'quantity': 70.88303,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 2.45871409,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 2.89,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.03544151,
#   'feeAsset': 'USDT',
#   'quantity': 70.88303,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 2.45871409,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 2.89,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.01410302,
#   'feeAsset': 'USDT',
#   'quantity': 28.20605,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.97838104,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.15,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.2918713,
#   'feeAsset': 'USDT',
#   'quantity': 583.7426,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 20.24823373,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 23.8,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.16273664,
#   'feeAsset': 'USDT',
#   'quantity': 325.47329,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 11.28966645,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 13.27,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.01005607,
#   'feeAsset': 'USDT',
#   'quantity': 20.11214,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.69762822,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 0.82,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.527,
#   'fee': -0.39059247,
#   'feeAsset': 'USDT',
#   'quantity': 781.18495,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 27.09690102,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 31.85,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.528,
#   'fee': -0.10007424,
#   'feeAsset': 'USDT',
#   'quantity': 200.14848,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 6.95041156,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.16,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.528,
#   'fee': -0.10007424,
#   'feeAsset': 'USDT',
#   'quantity': 200.14848,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 6.95041156,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.16,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.528,
#   'fee': -0.01508472,
#   'feeAsset': 'USDT',
#   'quantity': 30.16944,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.04767233,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.23,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.528,
#   'fee': -0.14913024,
#   'feeAsset': 'USDT',
#   'quantity': 298.26048,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 10.35747605,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 12.16,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.528,
#   'fee': -0.3348072,
#   'feeAsset': 'USDT',
#   'quantity': 669.6144,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 23.25321516,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 27.3,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.528,
#   'fee': -0.0741972,
#   'feeAsset': 'USDT',
#   'quantity': 148.3944,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 5.15318504,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 6.05,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.529,
#   'fee': -0.01508533,
#   'feeAsset': 'USDT',
#   'quantity': 30.17067,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.04890233,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.23,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.529,
#   'fee': -0.06770004,
#   'feeAsset': 'USDT',
#   'quantity': 135.40008,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 4.707269,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 5.52,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718874124000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.529,
#   'fee': -0.0662283,
#   'feeAsset': 'USDT',
#   'quantity': 132.4566,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 4.60493706,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 5.4,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718873009000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.20511672,
#   'feeAsset': 'USDT',
#   'quantity': 1025.5836,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 225.8,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718873009000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.02761536,
#   'feeAsset': 'USDT',
#   'quantity': 138.0768,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 30.4,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718873005000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.06813,
#   'feeAsset': 'USDT',
#   'quantity': 136.26,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 30.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718873005000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.2843292,
#   'feeAsset': 'USDT',
#   'quantity': 568.6584,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 125.2,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718873005000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.0111279,
#   'feeAsset': 'USDT',
#   'quantity': 22.2558,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 4.9,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718873005000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.0084027,
#   'feeAsset': 'USDT',
#   'quantity': 16.8054,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 3.7,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718873005000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.7975752,
#   'feeAsset': 'USDT',
#   'quantity': 1595.1504,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 351.2,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718873005000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.0027252,
#   'feeAsset': 'USDT',
#   'quantity': 5.4504,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 1.2,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718873005000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.14261879,
#   'feeAsset': 'USDT',
#   'quantity': 285.2376,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 62.8,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718873005000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.0233913,
#   'feeAsset': 'USDT',
#   'quantity': 46.7826,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 10.3,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718873005000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.0036336,
#   'feeAsset': 'USDT',
#   'quantity': 7.2672,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 1.6,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718873005000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.542,
#   'fee': -0.07607849,
#   'feeAsset': 'USDT',
#   'quantity': 152.157,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 33.5,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.622,
#   'fee': -0.04222673,
#   'feeAsset': 'USDT',
#   'quantity': 84.45346,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 3.2439778,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 3.43,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.622,
#   'fee': -0.20029997,
#   'feeAsset': 'USDT',
#   'quantity': 400.59994,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 15.38761482,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 16.27,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.622,
#   'fee': -0.677105,
#   'feeAsset': 'USDT',
#   'quantity': 1354.21,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 52.01713678,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 55.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.622,
#   'fee': -0.1908205,
#   'feeAsset': 'USDT',
#   'quantity': 381.641,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 14.65937491,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 15.5,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.622,
#   'fee': -0.01009502,
#   'feeAsset': 'USDT',
#   'quantity': 20.19004,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.77552822,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 0.82,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.622,
#   'fee': -0.01501942,
#   'feeAsset': 'USDT',
#   'quantity': 30.03884,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.15383467,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.22,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.622,
#   'fee': -0.01501942,
#   'feeAsset': 'USDT',
#   'quantity': 30.03884,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.15383467,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.22,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.623,
#   'fee': -0.31468194,
#   'feeAsset': 'USDT',
#   'quantity': 629.36388,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 24.19934211,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 25.56,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.623,
#   'fee': -0.2003081,
#   'feeAsset': 'USDT',
#   'quantity': 400.61621,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 15.40388482,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 16.27,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.623,
#   'fee': -0.30003125,
#   'feeAsset': 'USDT',
#   'quantity': 600.06251,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 23.07269042,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 24.37,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.623,
#   'fee': -0.10021561,
#   'feeAsset': 'USDT',
#   'quantity': 200.43122,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 7.70667624,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.14,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.623,
#   'fee': -0.10021561,
#   'feeAsset': 'USDT',
#   'quantity': 200.43122,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 7.70667624,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.14,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.623,
#   'fee': -0.36343548,
#   'feeAsset': 'USDT',
#   'quantity': 726.87096,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 27.94853595,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 29.52,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.624,
#   'fee': -0.14183424,
#   'feeAsset': 'USDT',
#   'quantity': 283.66848,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 10.91826574,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 11.52,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.624,
#   'fee': -0.01058832,
#   'feeAsset': 'USDT',
#   'quantity': 21.17664,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.81507886,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 0.86,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.624,
#   'fee': -0.01058832,
#   'feeAsset': 'USDT',
#   'quantity': 21.17664,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.81507886,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 0.86,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.624,
#   'fee': -0.01502064,
#   'feeAsset': 'USDT',
#   'quantity': 30.04128,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.15627467,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.22,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.624,
#   'fee': -0.10021968,
#   'feeAsset': 'USDT',
#   'quantity': 200.43936,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 7.71481624,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.14,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.624,
#   'fee': -0.10021968,
#   'feeAsset': 'USDT',
#   'quantity': 200.43936,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 7.71481624,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 8.14,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.624,
#   'fee': -0.03779784,
#   'feeAsset': 'USDT',
#   'quantity': 75.59568,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 2.90964199,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 3.07,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.624,
#   'fee': -0.3078,
#   'feeAsset': 'USDT',
#   'quantity': 615.6,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 23.69415308,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 25.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718868187000,
#   'symbol': 'ETCUSDT',
#   'side': 'SELL',
#   'price': 24.624,
#   'fee': -0.05860512,
#   'feeAsset': 'USDT',
#   'quantity': 117.21024,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 4.51136674,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 4.76,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718675516000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.359,
#   'fee': -0.08478255,
#   'feeAsset': 'USDT',
#   'quantity': 169.5651,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 38.9,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718675516000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.359,
#   'fee': -0.13077,
#   'feeAsset': 'USDT',
#   'quantity': 261.54,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 60.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718675516000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.359,
#   'fee': -0.065385,
#   'feeAsset': 'USDT',
#   'quantity': 130.77,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 30.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718675516000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.359,
#   'fee': -0.33760455,
#   'feeAsset': 'USDT',
#   'quantity': 675.2091,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 154.9,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718675516000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.359,
#   'fee': -0.3814125,
#   'feeAsset': 'USDT',
#   'quantity': 762.825,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 175.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718674682000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.647,
#   'fee': -0.28263054,
#   'feeAsset': 'USDT',
#   'quantity': 1413.1527,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 304.1,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718674682000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.647,
#   'fee': -0.08987298,
#   'feeAsset': 'USDT',
#   'quantity': 449.3649,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 96.7,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718674682000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.647,
#   'fee': -0.069705,
#   'feeAsset': 'USDT',
#   'quantity': 139.41,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 30.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718674515000,
#   'symbol': 'SOLUSDT',
#   'side': 'BUY',
#   'price': 137.027,
#   'fee': -0.7536485,
#   'feeAsset': 'USDT',
#   'quantity': 1507.297,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'SOL',
#   'qty': 11.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718674515000,
#   'symbol': 'SOLUSDT',
#   'side': 'BUY',
#   'price': 137.027,
#   'fee': -0.2055405,
#   'feeAsset': 'USDT',
#   'quantity': 411.081,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'SOL',
#   'qty': 3.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718674494000,
#   'symbol': 'SOLUSDT',
#   'side': 'BUY',
#   'price': 137.246,
#   'fee': -0.960722,
#   'feeAsset': 'USDT',
#   'quantity': 1921.444,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'SOL',
#   'qty': 14.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718674446000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.642,
#   'fee': -0.1244056,
#   'feeAsset': 'USDT',
#   'quantity': 248.8112,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 53.6,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718674446000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.642,
#   'fee': -0.4720914,
#   'feeAsset': 'USDT',
#   'quantity': 944.1828,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 203.4,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718674446000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.642,
#   'fee': -0.0902869,
#   'feeAsset': 'USDT',
#   'quantity': 180.5738,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 38.9,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718674446000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.642,
#   'fee': -0.81235,
#   'feeAsset': 'USDT',
#   'quantity': 1624.7,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 350.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673423000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12541,
#   'fee': -0.23669883,
#   'feeAsset': 'USDT',
#   'quantity': 1183.49417,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 9437.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718673423000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12541,
#   'fee': -0.0075246,
#   'feeAsset': 'USDT',
#   'quantity': 37.623,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 300.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718673423000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12541,
#   'fee': -0.0025082,
#   'feeAsset': 'USDT',
#   'quantity': 12.541,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 100.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718673423000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12541,
#   'fee': -0.00827705,
#   'feeAsset': 'USDT',
#   'quantity': 16.55412,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 132.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673423000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12541,
#   'fee': -0.05975786,
#   'feeAsset': 'USDT',
#   'quantity': 119.51573,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 953.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673423000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12541,
#   'fee': -0.0025082,
#   'feeAsset': 'USDT',
#   'quantity': 5.0164,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 40.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673423000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12541,
#   'fee': -0.01454756,
#   'feeAsset': 'USDT',
#   'quantity': 29.09512,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 232.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673423000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12541,
#   'fee': -0.01348157,
#   'feeAsset': 'USDT',
#   'quantity': 26.96315,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 215.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673423000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12541,
#   'fee': -0.00263361,
#   'feeAsset': 'USDT',
#   'quantity': 5.26722,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 42.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673423000,
#   'symbol': 'DOGEUSDT',
#   'side': 'BUY',
#   'price': 0.12541,
#   'fee': -0.78243299,
#   'feeAsset': 'USDT',
#   'quantity': 1564.86598,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'DOGE',
#   'qty': 12478.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673344000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.765,
#   'fee': -0.647087,
#   'feeAsset': 'USDT',
#   'quantity': 1294.174,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 271.6,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673344000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.765,
#   'fee': -0.099112,
#   'feeAsset': 'USDT',
#   'quantity': 198.224,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 41.6,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673344000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.765,
#   'fee': -0.071475,
#   'feeAsset': 'USDT',
#   'quantity': 142.95,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 30.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673344000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.765,
#   'fee': -0.064804,
#   'feeAsset': 'USDT',
#   'quantity': 129.608,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 27.2,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673344000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.765,
#   'fee': -0.05408275,
#   'feeAsset': 'USDT',
#   'quantity': 108.1655,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 22.7,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673344000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.765,
#   'fee': -0.0633745,
#   'feeAsset': 'USDT',
#   'quantity': 126.749,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 26.6,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673336000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.471,
#   'fee': -0.48533333,
#   'feeAsset': 'USDT',
#   'quantity': 2426.66669,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 103.39,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718673336000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.471,
#   'fee': -0.06360641,
#   'feeAsset': 'USDT',
#   'quantity': 127.21282,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 5.42,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673336000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.471,
#   'fee': -0.01502144,
#   'feeAsset': 'USDT',
#   'quantity': 30.04288,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.28,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673336000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.471,
#   'fee': -0.11535996,
#   'feeAsset': 'USDT',
#   'quantity': 230.71993,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 9.83,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718673336000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.471,
#   'fee': -0.09247574,
#   'feeAsset': 'USDT',
#   'quantity': 184.95148,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 7.88,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671587000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.801,
#   'fee': -0.02952615,
#   'feeAsset': 'USDT',
#   'quantity': 59.0523,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 12.3,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671587000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.801,
#   'fee': -0.09962075,
#   'feeAsset': 'USDT',
#   'quantity': 199.2415,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 41.5,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671587000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.801,
#   'fee': -0.51634755,
#   'feeAsset': 'USDT',
#   'quantity': 1032.6951,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 215.1,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671587000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.801,
#   'fee': -0.072015,
#   'feeAsset': 'USDT',
#   'quantity': 144.03,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 30.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671587000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.801,
#   'fee': -0.2822988,
#   'feeAsset': 'USDT',
#   'quantity': 564.5976,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 117.6,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671165000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.732,
#   'fee': -0.37216522,
#   'feeAsset': 'USDT',
#   'quantity': 1860.82612,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 78.41,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718671165000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.732,
#   'fee': -0.35455608,
#   'feeAsset': 'USDT',
#   'quantity': 1772.7804,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 74.7,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718671165000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.732,
#   'fee': -0.094928,
#   'feeAsset': 'USDT',
#   'quantity': 474.64,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 20.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718671145000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.745,
#   'fee': -0.87471831,
#   'feeAsset': 'USDT',
#   'quantity': 4373.59155,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 184.19,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718671145000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.745,
#   'fee': -0.00973545,
#   'feeAsset': 'USDT',
#   'quantity': 48.67725,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 2.05,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718671145000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.745,
#   'fee': -0.01507807,
#   'feeAsset': 'USDT',
#   'quantity': 30.15615,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.27,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671145000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.745,
#   'fee': -0.09296167,
#   'feeAsset': 'USDT',
#   'quantity': 185.92335,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 7.83,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671145000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.745,
#   'fee': -0.1700142,
#   'feeAsset': 'USDT',
#   'quantity': 340.0284,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 14.32,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671145000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.745,
#   'fee': -0.01080397,
#   'feeAsset': 'USDT',
#   'quantity': 21.60795,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 0.91,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671135000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.732,
#   'fee': -0.01506982,
#   'feeAsset': 'USDT',
#   'quantity': 30.13964,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.27,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671135000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.732,
#   'fee': -0.23732,
#   'feeAsset': 'USDT',
#   'quantity': 474.64,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 20.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671135000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.732,
#   'fee': -0.17893928,
#   'feeAsset': 'USDT',
#   'quantity': 357.87856,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 15.08,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671135000,
#   'symbol': 'ETCUSDT',
#   'side': 'BUY',
#   'price': 23.732,
#   'fee': -0.01447652,
#   'feeAsset': 'USDT',
#   'quantity': 28.95304,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETC',
#   'qty': 1.22,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.30440696,
#   'feeAsset': 'USDT',
#   'quantity': 1522.0348,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 314.6,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.0031447,
#   'feeAsset': 'USDT',
#   'quantity': 6.2894,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 1.3,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.0084665,
#   'feeAsset': 'USDT',
#   'quantity': 16.933,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 3.5,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.07257,
#   'feeAsset': 'USDT',
#   'quantity': 145.14,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 30.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.8413282,
#   'feeAsset': 'USDT',
#   'quantity': 1682.6564,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 347.8,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.14514,
#   'feeAsset': 'USDT',
#   'quantity': 290.28,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 60.0,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.0926477,
#   'feeAsset': 'USDT',
#   'quantity': 185.2954,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 38.3,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.0232224,
#   'feeAsset': 'USDT',
#   'quantity': 46.4448,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 9.6,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.0026609,
#   'feeAsset': 'USDT',
#   'quantity': 5.3218,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 1.1,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.4397742,
#   'feeAsset': 'USDT',
#   'quantity': 879.5484,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 181.8,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718671123000,
#   'symbol': 'FILUSDT',
#   'side': 'BUY',
#   'price': 4.838,
#   'fee': -0.1098226,
#   'feeAsset': 'USDT',
#   'quantity': 219.6452,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'FIL',
#   'qty': 45.4,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1718434863000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 426.01,
#   'fee': -0.01150227,
#   'feeAsset': 'USDT',
#   'quantity': 23.00454,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.14210755,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.054,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718434863000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 426.01,
#   'fee': -0.01001123,
#   'feeAsset': 'USDT',
#   'quantity': 20.02247,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.1236862,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.047,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1718434863000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 426.02,
#   'fee': -0.3812879,
#   'feeAsset': 'USDT',
#   'quantity': 762.5758,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 4.72850215,
# ...
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.11,
#   'fee': -2.4061583,
#   'feeAsset': 'USDT',
#   'quantity': 4812.3166,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 53.97339418,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 11.06,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.13,
#   'fee': -0.01044312,
#   'feeAsset': 'USDT',
#   'quantity': 20.88624,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.23520257,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.048,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.14,
#   'fee': -0.09464295,
#   'feeAsset': 'USDT',
#   'quantity': 189.2859,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 2.13587336,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.435,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.18,
#   'fee': -0.15731756,
#   'feeAsset': 'USDT',
#   'quantity': 314.63514,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 3.57888884,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.723,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.18,
#   'fee': -0.05113365,
#   'feeAsset': 'USDT',
#   'quantity': 102.2673,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.16326262,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.235,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.19,
#   'fee': -0.02001874,
#   'feeAsset': 'USDT',
#   'quantity': 40.03748,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.45632494,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.092,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.2,
#   'fee': -0.477632,
#   'feeAsset': 'USDT',
#   'quantity': 955.264,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 10.90926792,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 2.195,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.2,
#   'fee': -0.0650624,
#   'feeAsset': 'USDT',
#   'quantity': 130.1248,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.48604606,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.299,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.21,
#   'fee': -0.1088025,
#   'feeAsset': 'USDT',
#   'quantity': 217.605,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 2.49002686,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.5,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.22,
#   'fee': -0.19193202,
#   'feeAsset': 'USDT',
#   'quantity': 383.86404,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 4.40122738,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.882,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.23,
#   'fee': -0.02132627,
#   'feeAsset': 'USDT',
#   'quantity': 42.65254,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.49000526,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.098,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.24,
#   'fee': -0.10881,
#   'feeAsset': 'USDT',
#   'quantity': 217.62,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 2.50502686,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.5,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.24,
#   'fee': -0.10881,
#   'feeAsset': 'USDT',
#   'quantity': 217.62,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 2.50502686,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.5,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.26,
#   'fee': -0.19194966,
#   'feeAsset': 'USDT',
#   'quantity': 383.89932,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 4.43650738,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.882,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715776296000,
#   'symbol': 'BCHUSDT',
#   'side': 'SELL',
#   'price': 435.28,
#   'fee': -0.10163788,
#   'feeAsset': 'USDT',
#   'quantity': 203.27576,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 2.35837508,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.467,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715772276000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 424.66,
#   'fee': -0.1125349,
#   'feeAsset': 'USDT',
#   'quantity': 225.0698,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.53,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715772276000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 424.66,
#   'fee': -0.65801067,
#   'feeAsset': 'USDT',
#   'quantity': 1316.02134,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 3.099,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715772276000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 424.66,
#   'fee': -0.106165,
#   'feeAsset': 'USDT',
#   'quantity': 212.33,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.5,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715772276000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 424.66,
#   'fee': -0.09363753,
#   'feeAsset': 'USDT',
#   'quantity': 187.27506,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.441,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715772276000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 424.66,
#   'fee': -0.02951387,
#   'feeAsset': 'USDT',
#   'quantity': 59.02774,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.139,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771666000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 426.35,
#   'fee': -0.0972078,
#   'feeAsset': 'USDT',
#   'quantity': 194.4156,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.456,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771666000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 426.35,
#   'fee': -0.15625727,
#   'feeAsset': 'USDT',
#   'quantity': 312.51455,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.733,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771666000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 426.35,
#   'fee': -0.14581169,
#   'feeAsset': 'USDT',
#   'quantity': 291.6234,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.684,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771666000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 426.35,
#   'fee': -0.01065875,
#   'feeAsset': 'USDT',
#   'quantity': 21.3175,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.05,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771666000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 426.35,
#   'fee': -0.1065875,
#   'feeAsset': 'USDT',
#   'quantity': 213.175,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.5,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771666000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 426.35,
#   'fee': -0.0997659,
#   'feeAsset': 'USDT',
#   'quantity': 199.5318,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.468,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771666000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 426.35,
#   'fee': -0.22489962,
#   'feeAsset': 'USDT',
#   'quantity': 449.79925,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 1.055,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771666000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 426.35,
#   'fee': -0.1586022,
#   'feeAsset': 'USDT',
#   'quantity': 317.2044,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.744,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771105000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 428.59,
#   'fee': -0.30498464,
#   'feeAsset': 'USDT',
#   'quantity': 1524.92322,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 3.558,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715771100000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 428.59,
#   'fee': -0.00505736,
#   'feeAsset': 'USDT',
#   'quantity': 25.28681,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.059,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715771084000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 428.59,
#   'fee': -0.01500065,
#   'feeAsset': 'USDT',
#   'quantity': 30.0013,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.07,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771084000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 428.59,
#   'fee': -0.18879389,
#   'feeAsset': 'USDT',
#   'quantity': 377.58779,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.881,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771084000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 428.59,
#   'fee': -0.01050045,
#   'feeAsset': 'USDT',
#   'quantity': 21.00091,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.049,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715771084000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 428.59,
#   'fee': -0.01050045,
#   'feeAsset': 'USDT',
#   'quantity': 21.00091,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.049,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715766800000,
#   'symbol': 'ETHUSDT',
#   'side': 'SELL',
#   'price': 2929.52,
#   'fee': -1.19670892,
#   'feeAsset': 'USDT',
#   'quantity': 2393.41784,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 27.31816947,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETH',
#   'qty': 0.817,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715766800000,
#   'symbol': 'ETHUSDT',
#   'side': 'SELL',
#   'price': 2929.52,
#   'fee': -0.04980184,
#   'feeAsset': 'USDT',
#   'quantity': 99.60368,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.13686384,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETH',
#   'qty': 0.034,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715766800000,
#   'symbol': 'ETHUSDT',
#   'side': 'SELL',
#   'price': 2929.52,
#   'fee': -2.92952,
#   'feeAsset': 'USDT',
#   'quantity': 5859.04,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 66.87434389,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETH',
#   'qty': 2.0,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715766800000,
#   'symbol': 'ETHUSDT',
#   'side': 'SELL',
#   'price': 2929.52,
#   'fee': -0.06151992,
#   'feeAsset': 'USDT',
#   'quantity': 123.03984,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 1.40436122,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETH',
#   'qty': 0.042,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715766800000,
#   'symbol': 'ETHUSDT',
#   'side': 'SELL',
#   'price': 2929.52,
#   'fee': -0.01025332,
#   'feeAsset': 'USDT',
#   'quantity': 20.50664,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.2340602,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETH',
#   'qty': 0.007,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715766800000,
#   'symbol': 'ETHUSDT',
#   'side': 'SELL',
#   'price': 2929.52,
#   'fee': -0.04247804,
#   'feeAsset': 'USDT',
#   'quantity': 84.95608,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.96967798,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETH',
#   'qty': 0.029,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715766800000,
#   'symbol': 'ETHUSDT',
#   'side': 'SELL',
#   'price': 2929.52,
#   'fee': -0.99310728,
#   'feeAsset': 'USDT',
#   'quantity': 1986.21456,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 22.67040257,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'ETH',
#   'qty': 0.678,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715764056000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 428.09,
#   'fee': -0.15796521,
#   'feeAsset': 'USDT',
#   'quantity': 315.93042,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.738,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715764056000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 428.09,
#   'fee': -0.01134438,
#   'feeAsset': 'USDT',
#   'quantity': 22.68877,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.053,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715764056000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 428.09,
#   'fee': -0.01134438,
#   'feeAsset': 'USDT',
#   'quantity': 22.68877,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.053,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715764056000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 428.09,
#   'fee': -0.81915021,
#   'feeAsset': 'USDT',
#   'quantity': 1638.30043,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 3.827,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715762225000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 430.04,
#   'fee': -0.14690166,
#   'feeAsset': 'USDT',
#   'quantity': 734.50832,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 1.708,
#   'positionSide': 'LONG',
#   'activeBuy': False},
#  {'time': 1715762197000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 430.04,
#   'fee': -0.03246802,
#   'feeAsset': 'USDT',
#   'quantity': 64.93604,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.151,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715762197000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 430.04,
#   'fee': -0.01010594,
#   'feeAsset': 'USDT',
#   'quantity': 20.21188,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.047,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  {'time': 1715762197000,
#   'symbol': 'BCHUSDT',
#   'side': 'BUY',
#   'price': 430.04,
#   'fee': -0.0150514,
#   'feeAsset': 'USDT',
#   'quantity': 30.1028,
#   'quantityAsset': 'USDT',
#   'realizedProfit': 0.0,
#   'realizedProfitAsset': 'USDT',
#   'baseAsset': 'BCH',
#   'qty': 0.07,
#   'positionSide': 'LONG',
#   'activeBuy': True},
#  ...]

# %%
# Displaying sample parsed trade history
print(data['Trade_History'].iloc[0][:2])
# Out:
# [{'time': 1718899656000, 'symbol': 'SOLUSDT', 'side': 'BUY', 'price': 132.537, 'fee': -0.9940275, 'feeAsset': 'USDT', 'quantity': 1988.055, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'SOL', 'qty': 15.0, 'positionSide': 'LONG', 'activeBuy': True}, {'time': 1718899618000, 'symbol': 'DOGEUSDT', 'side': 'BUY', 'price': 0.12182, 'fee': -0.27979617, 'feeAsset': 'USDT', 'quantity': 1398.98088, 'quantityAsset': 'USDT', 'realizedProfit': 0.0, 'realizedProfitAsset': 'USDT', 'baseAsset': 'DOGE', 'qty': 11484.0, 'positionSide': 'LONG', 'activeBuy': False}]

# %% [markdown]
# # Feature Engineering

# %%
# Function to calculate financial metrics
def calculate_metrics(trades):
    # Convert trade history into DataFrame
    trades_data = pd.DataFrame(trades)
    
    # Ensure relevant columns exist
    if 'realizedProfit' not in trades_data.columns or 'quantity' not in trades_data.columns:
        return None  # Skip accounts with missing data

    # Calculating total profit and loss (PnL)
    total_pnl = trades_data['realizedProfit'].sum()
    
    # Calculating ROI (Return on Investment)
    total_investment = trades_data['quantity'].sum()
    roi = (total_pnl / total_investment) * 100 if total_investment != 0 else 0

    # Calculating win rate
    win_positions = (trades_data['realizedProfit'] > 0).sum()
    total_positions = len(trades_data)
    win_rate = (win_positions / total_positions) * 100 if total_positions != 0 else 0

    # Calculating Sharpe Ratio
    returns = trades_data['realizedProfit']
    if len(returns) > 1:
        sharpe_ratio = np.mean(returns) / np.std(returns) if np.std(returns) != 0 else 0
    else:
        sharpe_ratio = 0

    # Calculating Maximum Drawdown (MDD)
    cumulative_pnl = trades_data['realizedProfit'].cumsum()
    peak = cumulative_pnl.cummax()
    drawdown = peak - cumulative_pnl
    max_drawdown = drawdown.max()

    return {
        'ROI': roi,
        'PnL': total_pnl,
        'Sharpe_Ratio': sharpe_ratio,
        'MDD': max_drawdown,
        'Win_Rate': win_rate,
        'Win_Positions': win_positions,
        'Total_Positions': total_positions
    }

# %%
# Applying function to all accounts
metrics_list = []
for _, row in data.iterrows():
    metrics = calculate_metrics(row['Trade_History'])
    if metrics:
        metrics['Port_ID'] = row['Port_IDs']
        metrics_list.append(metrics)

# Creating new DataFrame
metrics_data = pd.DataFrame(metrics_list)

# Displaying the  results
print(metrics_data.head())
# Out:
#         ROI          PnL  Sharpe_Ratio          MDD   Win_Rate  Win_Positions  \
# 0  0.375303  6789.436739      0.274968   162.057536  33.333333            486
# 1  2.492178  3686.969761      0.125892    38.336310  18.576389            107
# 2  0.156489   772.729032      0.072410   205.532658  28.514694            359
# 3  0.828347  3658.765062      0.119475   175.481291  55.283308            361
# 4  0.135459  1309.459960      0.050312  1119.093200  34.100418            163
#
#    Total_Positions              Port_ID
# 0             1458  3925368433214965504
# 1              576  4002413037164645377
# 2             1259  3923766029921022977
# 3              653  3994879592543698688
# 4              478  3926423286576838657

# %% [markdown]
# # Creating Ranking Algorithm

# %%
# Defined weights for ranking
weights = {
    'ROI': 0.4,
    'Sharpe_Ratio': 0.2,
    'Win_Rate': 0.2,
    'PnL': 0.1,
    'MDD': -0.1

# %%
# Compute final ranking score
metrics_data['Score'] = (
    metrics_data['ROI'] * weights['ROI'] +
    metrics_data['Sharpe_Ratio'] * weights['Sharpe_Ratio'] +
    metrics_data['Win_Rate'] * weights['Win_Rate'] +
    metrics_data['PnL'] * weights['PnL'] +
    metrics_data['MDD'] * weights['MDD']
)

# %%
# Rank and get top 20 accounts
top_20 = metrics_data.sort_values(by='Score', ascending=False).head(20)

# %%
# Saviing results
metrics_data.to_csv("calculated_metrics.csv", index=False)
top_20.to_csv("top_20_accounts.csv", index=False)

# %%
# Display top 20
print(top_20)
# Out:
#           ROI           PnL  Sharpe_Ratio           MDD   Win_Rate  \
# 82   0.311561  71998.855953      0.060753  21338.051188  32.942149
# 126  0.543673  42574.473679      0.227530    300.813848  52.321981
# 23   0.404420  26427.331592      0.068271   2537.866629  31.391201
# 64   0.233296  19567.471286      0.162982   2234.000000  51.568381
# 146  0.406480  17601.401398      0.275925    585.677600  54.294032
# 35   0.871628  16337.461881      0.329833      2.381947  78.221722
# 22   1.032230  16790.012238      0.099541    635.050015  51.557712
# 118  1.099242  18015.997370      0.222756   2060.707122  61.397148
# 87   0.233080  14197.577076      0.299815    385.075554  52.765957
# 43   0.836806  13960.966457      0.152937   1772.219440  44.607364
# 107  0.308240  11298.706390      0.266628    509.550000  42.131980
# 60   1.791054  10681.514000      0.306751      0.000000  30.000000
# 75   1.016280   9775.389110      0.204154     87.003360  37.460317
# 25   0.468031   9603.585360      0.262785    214.715155  35.714286
# 5    0.557013  12464.606315      0.049887   3386.656094  22.826446
# 84   0.571080  10374.965290      0.050800   1651.131700  40.165289
# 94   0.708843   7581.491983      0.299166     97.203725  45.752928
# 108  0.145907   9314.494060      0.074096   1828.494702  26.472899
# 119  0.899440   7195.178325      0.221802     38.208100  74.539632
# 0    0.375303   6789.436739      0.274968    162.057536  33.333333
#
#      Win_Positions  Total_Positions              Port_ID        Score
# 82            1993             6050  4020204877254599680  5072.805681
# 126           2366             4522  3999240873283311617  4238.093355
# 23             528             1682  4021669203289716224  2395.400159
# 64            1233             2391  3960874214179953664  1743.786720
# 146            373              687  4028701921959171840  1712.648963
# 35            2780             3554  3986814617275053313  1649.566956
# 22            2019             3916  3956076827719377409  1626.240565
# 118           2540             4137  3907081197088384000  1608.292702
# 87             372              705  4022565861939831809  1391.956539
# 43            1369             3069  3788465932399412480  1228.161484
# 107            166              394  4008711265867865600  1087.518657
# 60               6               20  3936410995029308417  1074.929172
# 75             118              315  3939318616482048768   976.777981
# 25              95              266  3998572645139652353   946.269647
# 5             1381             6050  3987739404272887297   912.593094
# 84            2430             6050  3931992636670880512   880.655009
# 94            2774             6063  3944088772635000577   757.922782
# 108            337             1273  3962024093501274881   753.967698
# 119            931             1249  3886752488982104320   731.009085
# 0              486             1458  3925368433214965504   669.609702
